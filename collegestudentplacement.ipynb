# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]

import kagglehub
from kagglehub import KaggleDatasetAdapter

# Dataset identifier from Kaggle
dataset = "vrajesh0sharma7/college-student-placement"

# File path inside the dataset
file_path = "CollegePlacement.csv"  # relative path inside dataset

# Load dataset as a pandas DataFrame
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    dataset,
    file_path   # pass as positional argument
)

print("First 5 records:")
print(df.head())
# Out:
# /tmp/ipykernel_36/2874917166.py:14: DeprecationWarning: load_dataset is deprecated and will be removed in a future version.
#   df = kagglehub.load_dataset(
# First 5 records:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# 3                   1        No
# 4                   2        No

# %%
df.sample(5)
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 1594    CLG0025   64             7.37  7.30                     6
# 2548    CLG0051  115             9.30  9.45                     9
# 4929    CLG0074   97             5.58  5.92                     1
# 6244    CLG0085   90            10.00  9.86                     5
# 4470    CLG0070  104             9.01  8.98                     2
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 1594                    No                       8                     8
# 2548                    No                       0                    10
# 4929                    No                       6                     9
# 6244                    No                       0                     4
# 4470                    No                       7                     4
#
#       Projects_Completed Placement
# 1594                   5        No
# 2548                   1       Yes
# 4929                   0        No
# 6244                   5        No
# 4470                   3        No

# %%
df.describe()
# Out:
#                  IQ  Prev_Sem_Result          CGPA  Academic_Performance  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      99.471800         7.535673      7.532379              5.546400
# std       15.053101         1.447519      1.470141              2.873477
# min       41.000000         5.000000      4.540000              1.000000
# 25%       89.000000         6.290000      6.290000              3.000000
# 50%       99.000000         7.560000      7.550000              6.000000
# 75%      110.000000         8.790000      8.770000              8.000000
# max      158.000000        10.000000     10.460000             10.000000
#
#        Extra_Curricular_Score  Communication_Skills  Projects_Completed
# count            10000.000000          10000.000000        10000.000000
# mean                 4.970900              5.561800            2.513400
# std                  3.160103              2.900866            1.715959
# min                  0.000000              1.000000            0.000000
# 25%                  2.000000              3.000000            1.000000
# 50%                  5.000000              6.000000            3.000000
# 75%                  8.000000              8.000000            4.000000
# max                 10.000000             10.000000            5.000000

# %%
df.columns
# Out:
# Index(['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %%
df1 = df[['CGPA','IQ','Placement']]

# %%
df1.sample(5)
# Out:
#       CGPA   IQ Placement
# 9112  7.01  115       Yes
# 3     5.75  122        No
# 3123  7.29   94        No
# 970   7.80  101        No
# 5750  8.33   99        No

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df1['CGPA'],df1['IQ'],c=color_map)
plt.xlabel('cgpa')
plt.ylabel('iq')
plt.title('map')
# Out:
# Text(0.5, 1.0, 'map')

# %%
X=df1.iloc[:,:2]
X
# Out:
#       CGPA   IQ
# 0     6.28  107
# 1     5.37   97
# 2     5.83  109
# 3     5.75  122
# 4     7.69   96
# ...    ...  ...
# 9995  8.29  119
# 9996  9.34   70
# 9997  6.25   89
# 9998  8.92  107
# 9999  9.77  109
#
# [10000 rows x 2 columns]

# %%
y= df.iloc[:,-1]
y
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 9995    Yes
# 9996     No
# 9997     No
# 9998     No
# 9999     No
# Name: Placement, Length: 10000, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train,y_train)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,y_pred))

# %%
lr.coef_

# %%
lr.intercept_
